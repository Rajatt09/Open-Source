# %%
def print_book(d1):
    for k in d1.keys():
        
            print("book1 detail is: ")
            print("title", d1[k][title], "\n author", d1[k]["author"], "\n genre", d1[k]["genre"], "\n status", d1[k]["status"], "\n")
            


def add_book(d1):
    title=input("Enter book title: ")
    author=input("Enter book author: ")
    isbn=input("Enter isbn: ")
    genre=input("Enter genre: ")
    status=input("Enter status: ")
    d1[title]={
        "author": author,
        "isbn": isbn,
        "genre": genre,
        "status": status
    }
    
def update_book_details(d1):
    book=input("Enter book title you want to update detail: ")
    
    key=input("what detail you want to update (title-t, author-a, genre-g, status-s, isbn-i: ");
    if (key=='t'):
        val=input("Enter title of the book: ")
    elif (key=='a'):
        val=input("Enter author of the book: ")
    elif (key=='g'):
        val=input("Enter genre of the book: ")
    elif (key=='s'):
        val=input("Enter status of the book: ")
                  
    d1[book][key]=val
                  
    print("book detail updated.")
                  

def search_by_isbn(d1):
    key=input("Enter isbn of the book you want to search for: ")
    for k in d1.keys():
        if (d1[k]["isbn"]==key):
            print("book detail is: ")
            print("title", d1[k][title], "\n author", d1[k]["author"], "\n genre", d1[k]["genre"], "\n status", d1[k]["status"])
            return
    print("No such book exists")
            
def genrate_genre_report(d1):
    for k in d1.keys():
        if (d1[k]["status"] == "available"):
            print("book details are: \n")
            print("genre", d1[k]["genre"], ",status", d1[k]["status"])
        
    

                  
d1={}


while (1):
    info=input("What do you want to do? : add-a, update-u, search-s,generate-g, print-p, exit-e: ")
    if (info=='a'):
        add_book(d1)
    elif(info=='u'):
        update_book_details(d1)
    elif(info=='s'):
        search_by_isbn(d1)
    elif(info=='g'):
        genrate_genre_report(d1)
    elif(info=='p'):
        print_book(d1)
    elif(info=='e'):
        break
